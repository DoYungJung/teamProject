# %%
# 숫자 및 데이터 다루는 라이브러리
import numpy as np
import pandas as pd

# %%
### CSV 파일을 읽어 DataFrame 변수에 저장하기
### 1페이지_이름 순 정렬
data1 = pd.read_csv("./fixed_건대_Age.csv", encoding="ms949")
data1
# Out:
#                   name     tenCen     twoCen   threeCen    fourCen    fiveCen  \
# 0    60년전통신촌황소곱창 건대직영점  33.188471  47.724471  34.401882  31.032000  36.248706
# 1               972Bar  47.798333  81.895667  34.080667  23.921667  22.567667
# 2               972Bar  47.798333  81.895667  34.080667  23.921667  22.567667
# 3                 C156  39.557882  50.124941  34.868471  25.737176  20.728235
# 4            CUCINA843  11.764706  48.062353  36.857647  26.397412  17.508941
# ..                 ...        ...        ...        ...        ...        ...
# 298          환이네갈비살 본점  25.000000  86.042500  81.087500  83.034500  81.255500
# 299                 후토  11.764706  52.832471  40.008706  26.120000  17.046118
# 300              훈춘양꼬치  71.566500  91.771000  83.253000  85.652000  68.566500
# 301                 흐릇  11.764706  47.174824  34.175529  20.912941  11.764706
# 302          흥에취한범 건대점  32.551333  89.588000  32.777667  23.691667  24.074333
#
# ...

# %%
data2 = pd.read_csv("./fixed_건대_Category.csv", encoding="ms949")

# %%
len(data1)
# Out:
# 303

# %%
len(data2)
# Out:
# 305

# %%
data3 = pd.merge(left=data1, right=data2, on=["name"], how="inner")

# %%
data3.drop_duplicates()
# Out:
#                   name     tenCen     twoCen   threeCen    fourCen    fiveCen  \
# 0    60년전통신촌황소곱창 건대직영점  33.188471  47.724471  34.401882  31.032000  36.248706
# 1               972Bar  47.798333  81.895667  34.080667  23.921667  22.567667
# 3                 C156  39.557882  50.124941  34.868471  25.737176  20.728235
# 4            CUCINA843  11.764706  48.062353  36.857647  26.397412  17.508941
# 5            LITE LANE  42.684706  48.135529  32.104235  23.636000  11.764706
# ..                 ...        ...        ...        ...        ...        ...
# 308          환이네갈비살 본점  25.000000  86.042500  81.087500  83.034500  81.255500
# 309                 후토  11.764706  52.832471  40.008706  26.120000  17.046118
# 310              훈춘양꼬치  71.566500  91.771000  83.253000  85.652000  68.566500
# 311                 흐릇  11.764706  47.174824  34.175529  20.912941  11.764706
# 313          흥에취한범 건대점  32.551333  89.588000  32.777667  23.691667  24.074333
#
# ...
